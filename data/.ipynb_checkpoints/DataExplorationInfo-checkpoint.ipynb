# %%
# Import dependencies.

import json
import pandas as pd
import numpy as np
import sklearn as skl
import numpy
import datetime
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

# From dependency imports
#from mpl_toolkits.mplot3d import Axes3D
#from sklearn.linear_model import LinearRegression
#from sklearn.model_selection import train_test_split
#from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder, MinMaxScaler
#from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
#from sklearn.datasets import make_blobs
#from sklearn.metrics import accuracy_score,r2_score
#from sklearn.linear_model import LogisticRegression
from sqlalchemy import create_engine
#from tensorflow.keras.models import Sequential
#from tensorflow.keras.layers import Dense
# Out:
# C:\Users\dcohen\.conda\envs\PythonData\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\dcohen\.conda\envs\PythonData\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\dcohen\.conda\envs\PythonData\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
### Configure settings for Relational Database Service, and defining database info in config variable.
jdbc_url="jdbc:postgresql://34.67.52.115/team5k"
config = {'user': 'postgres', 
          "password": "team5kteam5k", 
          "driver":"org.postgresql.Driver",
          "location": "34.67.52.115",
          "db": "team5k",
          "port": "5432"}

# %%
### Creating variable holding postgres info in format "postgres://[user]:[password]@[location]:[port]/[database]".
create_engine_str = ('postgresql://' 
                     + config["user"] 
                     + ":" + config["password"] 
                     + "@" + config["location"] 
                     + ":" + config["port"] 
                     + "/" + config["db"])

# %%
# Connecting to Postgres instance.
engine = create_engine(create_engine_str)

# %%
# Printing info for table names. 
print (engine.table_names())
# Out:
# ['committees', 'candidates', 'education', 'committee_summary_2020', 'six_state_donations', 'agg_county_votes', 'agg_county_donors', 'donations', 'fec_donor_az', 'health_metrics', 'birth_death_rate', 'postal_codes', 'fec_donor_mi', 'fec_donor_wi', 'fec_committee', 'fec_donor_pa', 'pres_votes_6t', 'unemployment', 'fec_donor_nc', 'fec_donor_fl']

# %%
# Create variables for data
#committees_df = pd.read_sql_query('select * from "committees"',con=engine)
#candidates_df = pd.read_sql_query('select * from "candidates"',con=engine)
#education_df = pd.read_sql_query('select * from "education"',con=engine)
#committee_summary_2020_df = pd.read_sql_query('select * from "committee_summary_2020"',con=engine)
#six_state_donations_df = pd.read_sql_query('select * from "six_state_donations"',con=engine)
#agg_county_votes_df = pd.read_sql_query('select * from "agg_county_votes"',con=engine)
#agg_county_donors_df = pd.read_sql_query('select * from "agg_county_donors"',con=engine)
#donations_df = pd.read_sql_query('select * from "donations"',con=engine)
#fec_donor_az_df = pd.read_sql_query('select * from "fec_donor_az"',con=engine)
#health_metrics_df = pd.read_sql_query('select * from "health_metrics"',con=engine)
#birth_death_rate_df = pd.read_sql_query('select * from "birth_death_rate"',con=engine)
#postal_codes_df = pd.read_sql_query('select * from "postal_codes"',con=engine)
#fec_donor_mi_df = pd.read_sql_query('select * from "fec_donor_mi"',con=engine)
#fec_donor_wi_df = pd.read_sql_query('select * from "fec_donor_wi"',con=engine)
#fec_committee_df = pd.read_sql_query('select * from "fec_committee"',con=engine)
#fec_donor_pa_df = pd.read_sql_query('select * from "fec_donor_pa"',con=engine)
#pres_votes_6t_df = pd.read_sql_query('select * from "pres_votes_6t"',con=engine)
#unemployment_df = pd.read_sql_query('select * from "unemployment"',con=engine)
#fec_donor_ncs_df = pd.read_sql_query('select * from "fec_donor_nc"',con=engine)
#fec_donor_fl_df = pd.read_sql_query('select * from "fec_donor_fl"',con=engine)

# %%
# Committee DB & description
committees_df = pd.read_sql_query('select * from "committees"',con=engine)
committees_df.describe()
# Out:
#           CMTE_ID               CMTE_NM        TRES_NM  \
# count      141375                141363         134526
# unique      49000                 53806          53968
# top     C90006701  COLLINS FOR CONGRESS  KILGORE, PAUL
# freq           11                    40            592
#
#                             CMTE_ST1 CMTE_ST2   CMTE_CITY CMTE_ST CMTE_ZIP  \
# count                         140886    26481      140905  140908   140785
# unique                         49708     5894        7837      66    16657
# top     1900 WEST OAKLAND PARK BLVD.        .  WASHINGTON      DC    20005
# freq                             903     1926       13490   15004     2677
#
#        CMTE_DSGN CMTE_TP CMTE_PTY_AFFILIATION CMTE_FILING_FREQ ORG_TP  \
# count     141326  141355                54106           141375  38771
# unique         6      16                  146                5      8
# top            U       H                  REP                Q      C
# ...

# %%
# Donations DB & description
#donations_df = pd.read_sql_query('select * from "donations"',con=engine)
#donations_df.describe()

# %%
# Health Metrics DB & description
health_metrics_df = pd.read_sql_query('select * from "health_metrics"',con=engine)
health_metrics_df.describe()
# Out:
#                fips     num_deaths  years_of_potential_life_lost_rate  \
# count   3193.000000    2900.000000                        2900.000000
# mean   30360.922643    2626.418621                        8560.596542
# std    15171.912105   14147.013596                        2593.841317
# min     1000.000000      32.000000                        2730.603992
# 25%    18173.000000     228.000000                        6769.680562
# 50%    29175.000000     487.500000                        8287.134501
# 75%    45075.000000    1187.000000                       10052.108422
# max    56045.000000  347916.000000                       29138.378057
#
#        95percent_ci_low  95percent_ci_high     quartile  ypll_rate_aian  \
# count       2900.000000        2900.000000  3084.000000      175.000000
# mean        7231.352606        9935.234974     2.460441    14948.402184
# std         2225.987099        3191.809731     1.117515     5786.739134
# ...

# %%
# Donations DB & description
agg_county_donors_df = pd.read_sql_query('select * from "agg_county_donors"',con=engine)
agg_county_donors_df.describe()
# Out:
#        index      blue_amt        red_amt    other_amt      total_amt  \
# count   67.0     67.000000      67.000000    67.000000      67.000000
# mean     0.0   4015.671642   13239.179104    14.925373   17269.776119
# std      0.0  13751.444026   26834.322713   122.169444   28630.114184
# min      0.0      0.000000       0.000000     0.000000     600.000000
# 25%      0.0      0.000000    1650.000000     0.000000    2250.000000
# 50%      0.0      0.000000    4000.000000     0.000000    5000.000000
# 75%      0.0      0.000000   11850.000000     0.000000   12500.000000
# max      0.0  79200.000000  136700.000000  1000.000000  136700.000000
#
#        percent_blue  percent_red  percent_other  election_year
# count     67.000000    67.000000      67.000000      67.000000
# mean       0.194063     0.802205       0.003731    2002.149254
# std        0.390675     0.389986       0.030542       2.009476
# min        0.000000     0.000000       0.000000    2000.000000
# ...

# %%
# Voters DB & description
agg_county_votes_df = pd.read_sql_query('select * from "agg_county_votes"',con=engine)
agg_county_votes_df.describe()
# Out:
#         index     blue_votes      red_votes    other_votes   total_votes  \
# count  2020.0    2020.000000    2020.000000    1920.000000  1.920000e+03
# mean      0.0   33658.082178   32940.009406    1439.081771  7.000121e+04
# std       0.0   76134.999908   57885.890155    4036.360996  1.351435e+05
# min       0.0     518.000000     179.000000       4.000000  1.233000e+03
# 25%       0.0    4659.000000    6114.000000     164.000000  1.126575e+04
# 50%       0.0    9639.000000   13037.000000     440.500000  2.393750e+04
# 75%       0.0   24950.500000   34350.000000    1198.250000  6.458675e+04
# max       0.0  702907.000000  749885.000000  117566.000000  1.567834e+06
#
#        percent_blue  percent_red  percent_other  election_year  PopPct_Urban  \
# count   1920.000000  1920.000000    1920.000000    2020.000000   2020.000000
# mean       0.431450     0.546959       0.021591    2008.000000     45.741559
# std        0.111499     0.109909       0.016759       5.658255     30.088229
# ...
