# %%
# Install Java, Spark, and Findspark
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q http://www-us.apache.org/dist/spark/spark-2.4.6/spark-2.4.6-bin-hadoop2.7.tgz
# !tar xf spark-2.4.6-bin-hadoop2.7.tgz
# !pip install -q findspark

# Set Environment Variables
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.6-bin-hadoop2.7"

# Start a SparkSession
import findspark
findspark.init()

# !wget https://jdbc.postgresql.org/download/postgresql-42.2.9.jar

# Start Spark session
from pyspark.sql import SparkSession
from pyspark.conf import SparkConf
from pyspark.sql.types import *

conf = SparkConf().set("spark.files.overwrite", "true").set('spark.driver.extraClassPath', '/content/postgresql-42.2.9.jar')
spark = SparkSession.builder.appName("ETL_Committee").config("spark.driver.extraClassPath","/content/postgresql-42.2.9.jar",conf=conf).getOrCreate()
# Out:
# --2020-08-04 13:55:37--  https://jdbc.postgresql.org/download/postgresql-42.2.9.jar
# Resolving jdbc.postgresql.org (jdbc.postgresql.org)... 72.32.157.228, 2001:4800:3e1:1::228
# Connecting to jdbc.postgresql.org (jdbc.postgresql.org)|72.32.157.228|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 914037 (893K) [application/java-archive]
# Saving to: ‘postgresql-42.2.9.jar’
#
# postgresql-42.2.9.j 100%[===================>] 892.61K  4.32MB/s    in 0.2s
#
# 2020-08-04 13:55:37 (4.32 MB/s) - ‘postgresql-42.2.9.jar’ saved [914037/914037]

# %%
#Create Function

def etl_load(table_name,  gcs_bucket, file_name, year):
  from pyspark import SparkFiles 
  
  #Define Schema
  schema = StructType([
    StructField("CMTE_ID",StringType(),True),
    StructField("CMTE_NM",StringType(),True),
    StructField("TRES_NM",StringType(),True),
    StructField("CMTE_ST1",StringType(),True),
    StructField("CMTE_ST2",StringType(),True),
    StructField("CMTE_CITY",StringType(),True),
    StructField("CMTE_ST",StringType(),True),
    StructField("CMTE_ZIP",StringType(),True),
    StructField("CMTE_DSGN",StringType(),True),
    StructField("CMTE_TP",StringType(),True),
    StructField("CMTE_PTY_AFFILIATION",StringType(),True),
    StructField("CMTE_FILING_FREQ",StringType(),True),
    StructField("ORG_TP",StringType(),True),
    StructField("CONNECTED_ORG_NM",StringType(),True),
    StructField("CAND_ID",StringType(),True)])
      
  #Unzip file and overwrite for the job
  url=gcs_bucket + file_name
  print(url)
  # !wget $url
  # !unzip -o  $file_name  
  new_file_name=year+file_name
  # !mv -f cm.txt $new_file_name

  spark.sparkContext.addFile(new_file_name)
  df = spark.read.csv(SparkFiles.get(new_file_name), sep="|", header=False, inferSchema=True, schema=schema)

  #Limit ETL to 6 States
  df.show()

  mode = "append"
  jdbc_url="jdbc:postgresql://34.67.52.115/team5k"
  postgres_config = {"user":"postgres", 
            "password": "team5kteam5k", 
            "driver":"org.postgresql.Driver"}

  print("Starting " +year)
  # Read in data to dataframe
  #df = pd.read_csv(year+"/itcont.txt", sep="|", low_memory=False)
  #df.head()
  # Write file
  df.write.jdbc(url=jdbc_url, table=table_name, mode=mode, properties=postgres_config)

  print(year + " Complete")

# %%
#Run ETL Function
etl_load('committees', 'https://storage.googleapis.com/team5k/donations/', 'cm00.zip','2000')
etl_load('committees', 'https://storage.googleapis.com/team5k/donations/', 'cm02.zip','2002')
etl_load('committees', 'https://storage.googleapis.com/team5k/donations/', 'cm04.zip','2004')
etl_load('committees', 'https://storage.googleapis.com/team5k/donations/', 'cm06.zip','2006')
etl_load('committees', 'https://storage.googleapis.com/team5k/donations/', 'cm08.zip','2008')
etl_load('committees', 'https://storage.googleapis.com/team5k/donations/', 'cm10.zip','2010')
etl_load('committees', 'https://storage.googleapis.com/team5k/donations/', 'cm12.zip','2012')
etl_load('committees', 'https://storage.googleapis.com/team5k/donations/', 'cm14.zip','2014')
etl_load('committees', 'https://storage.googleapis.com/team5k/donations/', 'cm16.zip','2016')
print("All Years Complete")
# Out:
# https://storage.googleapis.com/team5k/donations/cm00.zip
# --2020-08-03 14:05:53--  https://storage.googleapis.com/team5k/donations/cm00.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.216.128, 172.217.204.128, 172.217.203.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.216.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 448764 (438K) [application/x-zip-compressed]
# Saving to: ‘cm00.zip’
#
# cm00.zip            100%[===================>] 438.25K  --.-KB/s    in 0.004s
#
# 2020-08-03 14:05:53 (98.5 MB/s) - ‘cm00.zip’ saved [448764/448764]
#
# Archive:  cm00.zip
#   inflating: cm.txt
# +---------+--------------------+--------------------+--------------------+-------------+-------------+-------+--------+---------+-------+--------------------+----------------+------+--------------------+---------+
# |  CMTE_ID|             CMTE_NM|             TRES_NM|            CMTE_ST1|     CMTE_ST2|    CMTE_CITY|CMTE_ST|CMTE_ZIP|CMTE_DSGN|CMTE_TP|CMTE_PTY_AFFILIATION|CMTE_FILING_FREQ|ORG_TP|    CONNECTED_ORG_NM|  CAND_ID|
# +---------+--------------------+--------------------+--------------------+-------------+-------------+-------+--------+---------+-------+--------------------+----------------+------+--------------------+---------+
# |C00000042|ILLINOIS TOOL WOR...|     MICHAEL J LYNCH|3600 WEST LAKE AV...|         null|     GLENVIEW|     IL|   60025|        U|      Q|                null|               Q|     C|ILLINOIS TOOL WOR...|     null|
# |C00000059|HALLMARK POLITICA...|      GREG C SWARENS|2501 MCGEE STREET...|PO BOX 419580|  KANSAS CITY|     MO|   64141|        U|      Q|                 UNK|               M|     C|HALLMARK CARDS IN...|     null|
# |C00000125|ARCHER FOR CONGRE...|        MRS JO MARSH|2001 KIRBY DRIVE ...|            .|      HOUSTON|     TX|   77019|        P|      H|                 REP|               Q|  null|                null|H6TX07029|
# |C00000372|MAINTENANCE OF WA...|     WILLIAM E LARUE|26555 EVERGREEN R...|            .|   SOUTHFIELD|     MI|   48076|        U|      Q|                 UNK|               M|     L|MAINTENANCE OF WA...|     null|
# |C00000422|AMERICAN MEDICAL ...|        KEVIN WALKER|1101 VERMONT AVEN...|         null|   WASHINGTON|     DC|   20005|        U|      Q|                null|               M|     T|MEDICAL ASS'N: AM...|     null|
# |C00000489|D R I V E POLITIC...|       RONALD L COBB|      3528 WEST RENO|         null|OKLAHOMA CITY|     OK|   73107|        U|      Q|                null|               Q|     L|TEAMSTERS; INT'L ...|     null|
# |C00000547|KANSAS MEDICAL SO...|C. RICHARD BONEBR...|     623 SW 10TH AVE|         null|       TOPEKA|     KS|   66612|        U|      Q|                 UNK|               Q|     T|MEDICAL ASS'N; KA...|     null|
# |C00000638|INDIANA MEDICAL P...|     SCOTT WAGNER MD|322 CANAL WALK CA...|            .| INDIANAPOLIS|     IN|   46202|        U|      Q|                null|               Q|     T|MEDICAL ASS'N: AM...|     null|
# |C00000729|AMERICAN DENTAL P...|       DR JOHN REITZ|1111 14TH STREET,...|         null|   WASHINGTON|     DC|   20005|        U|      Q|                 UNK|               M|     T|DENTAL ASS'N; AME...|     null|
# |C00000794| LENT & SCRIVNER PAC|  MICHAEL S SCRIVNER|        P O BOX 2301|         null|    ARLINGTON|     VA|   22202|        U|      Q|                 UNK|               Q|  null|                null|     null|
# |C00000885|INTERNATIONAL UNI...|    JAMES A WILLIAMS|1750 NEW YORK AVE...|            .|   WASHINGTON|     DC|   20006|        U|      Q|                 UNK|               Q|     L|PAINTERS & ALLIED...|     null|
# |C00000901|BUILD POLITICAL A...|       JOSEPH BARNEY| 1201 15TH STREET NW|            .|   WASHINGTON|     DC|   20005|        U|      Q|                 UNK|               M|     T|HOME BUILDERS; NA...|     null|
# |C00000935|DEMOCRATIC CONGRE...|       DAVID PLOUFFE| 430 S CAPITOL ST SE|            .|   WASHINGTON|     DC|   20003|        U|      Y|                 DEM|               M|  null|DCCC - CONTRIBUTIONS|     null|
# |C00000984|UNITED STATES TEL...|     LISA M COSTELLO|1401 H STREET NW ...|            .|   WASHINGTON|     DC|   20005|        U|      Q|                 UNK|               M|     T|TELEPHONE ASSOCIA...|     null|
# |C00000992|BRANCH COUNTY REP...|     ROBERTA A SMITH|          PO BOX 127|            .|    COLDWATER|     MI|   49036|        U|      Y|                 REP|               Q|  null|MICHIGAN REPUBLIC...|     null|
# |C00001008|LOUISIANA MEDICAL...|  WILLIAM CASSIDY MD|6767 PERKINS ROAD...|         null|  BATON ROUGE|     LA|   70808|        U|      Q|                null|               Q|     T|LOUISIANA STATE M...|     null|
# |C00001016|CARPENTERS LEGISL...|         MONTE BYERS|101 CONSTITUTION ...|         null|   WASHINGTON|     DC|   20001|        U|      Q|                 NNE|               M|     L|CARPENTERS & JOIN...|     null|
# |C00001081|DICKINSON SECOND ...|     LLOYD LANCASTER|   2350 WOODLEY ROAD|         null|   MONTGOMERY|     AL|   36111|        P|      H|                 REP|               Q|  null|                null|H6AL02050|
# |C00001099|        D R I V E 42|         HUGO MORRIS|9300 FLAIR DRIVE ...|         null|     EL MONTE|     CA|   91731|        U|      Q|                 UNK|               Q|     L|TEAMSTERS; INT'L ...|     null|
# |C00001156|MICHIGAN LEAGUE O...|     ROBERT G HOWELL|200 WASHINGTON SQ...|         null|      LANSING|     MI|   48933|        U|      Q|                null|               Q|     T|MICHIGAN LEAGUE O...|     null|
# +---------+--------------------+--------------------+--------------------+-------------+-------------+-------+--------+---------+-------+--------------------+----------------+------+--------------------+---------+
# only showing top 20 rows
#
# Starting 2000
# rm: cannot remove 'itcont.txt': No such file or directory
# 2000 Complete
# https://storage.googleapis.com/team5k/donations/cm02.zip
# --2020-08-03 14:07:01--  https://storage.googleapis.com/team5k/donations/cm02.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.204.128, 172.217.203.128, 74.125.31.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.204.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 445668 (435K) [application/x-zip-compressed]
# Saving to: ‘cm02.zip’
#
# cm02.zip            100%[===================>] 435.22K  --.-KB/s    in 0.003s
#
# 2020-08-03 14:07:01 (127 MB/s) - ‘cm02.zip’ saved [445668/445668]
#
# Archive:  cm02.zip
#   inflating: cm.txt
# +---------+--------------------+--------------------+--------------------+-------------+-------------+-------+--------+---------+-------+--------------------+----------------+------+--------------------+---------+
# |  CMTE_ID|             CMTE_NM|             TRES_NM|            CMTE_ST1|     CMTE_ST2|    CMTE_CITY|CMTE_ST|CMTE_ZIP|CMTE_DSGN|CMTE_TP|CMTE_PTY_AFFILIATION|CMTE_FILING_FREQ|ORG_TP|    CONNECTED_ORG_NM|  CAND_ID|
# +---------+--------------------+--------------------+--------------------+-------------+-------------+-------+--------+---------+-------+--------------------+----------------+------+--------------------+---------+
# |C00000042|ILLINOIS TOOL WOR...|    Michael J. Lynch| 3600 W. Lake Avenue|         null|     Glenview|     IL|   60025|        U|      Q|                null|               Q|     C|ILLINOIS TOOL WOR...|     null|
# |C00000059|HALLMARK POLITICA...|      GREG C SWARENS|2501 MCGEE STREET...|PO BOX 419580|  KANSAS CITY|     MO|   64141|        U|      Q|                 UNK|               M|     C|HALLMARK CARDS IN...|     null|
# |C00000125|ARCHER FOR CONGRE...|        MRS JO MARSH|2001 KIRBY DRIVE ...|            .|      HOUSTON|     TX|   77019|        P|      H|                 REP|               Q|  null|                null|H6TX07029|
# |C00000372|MAINTENANCE OF WA...|     WILLIAM E LARUE|26555 EVERGREEN R...|            .|   SOUTHFIELD|     MI|   48076|        U|      Q|                 UNK|               M|     L|MAINTENANCE OF WA...|     null|
# |C00000422|AMERICAN MEDICAL ...|       WALKER, KEVIN|1101 VERMONT AVEN...|   12TH FLOOR|   WASHINGTON|     DC|   20005|        U|      Q|                null|               M|     T|MEDICAL ASS'N: AM...|     null|
# |C00000489|D R I V E POLITIC...|       RONALD L COBB|      3528 WEST RENO|         null|OKLAHOMA CITY|     OK|   73107|        U|      Q|                null|               Q|     L|TEAMSTERS; INT'L ...|     null|
# |C00000547|KANSAS MEDICAL SO...|C. RICHARD BONEBR...|     623 SW 10TH AVE|         null|       TOPEKA|     KS|   66612|        U|      Q|                 UNK|               Q|     T|MEDICAL ASS'N; KA...|     null|
# |C00000638|INDIANA MEDICAL P...|     BARRY GLAZER MD|322 CANAL WALK CA...|            .| INDIANAPOLIS|     IN|   46202|        U|      Q|                null|               Q|     T|MEDICAL ASS'N: AM...|     null|
# |C00000729|AMERICAN DENTAL P...|        Edward Vigna| 1111 14th Street NW|   Suite 1100|   Washington|     DC|   20005|        U|      Q|                 UNK|               M|     T|DENTAL ASS'N; AME...|     null|
# |C00000794| LENT & SCRIVNER PAC|  MICHAEL S SCRIVNER|         PO BOX 2715|         null|    ARLINGTON|     VA|   22202|        U|      Q|                 UNK|               Q|  null|                null|     null|
# |C00000885|INTERNATIONAL UNI...|        George Galis|1750 New York Ave...|            .|   Washington|     DC|   20006|        U|      Q|                 UNK|               Q|     L|       IUPAT PAT LEC|     null|
# |C00000901|BUILD POLITICAL A...|       JOSEPH BARNEY| 1201 15TH STREET NW|            .|   WASHINGTON|     DC|   20005|        U|      Q|                 UNK|               M|     T|HOME BUILDERS; NA...|     null|
# |C00000935|DEMOCRATIC CONGRE...|     Wolfson, Howard|430 South Capitol...|    2nd Floor|   Washington|     DC|   20003|        U|      Y|                 DEM|               M|  null|    Democratic Unity|     null|
# |C00000984|UNITED STATES TEL...|      Laura Van Hove|    1401 H Street NW|    Suite 600|   Washington|     DC|   20005|        U|      Q|                 UNK|               M|     T|United States Tel...|     null|
# |C00000992|BRANCH COUNTY REP...|     ROBERTA A SMITH|          PO BOX 127|            .|    COLDWATER|     MI|   49036|        U|      Y|                 REP|               Q|  null|MICHIGAN REPUBLIC...|     null|
# |C00001008|LOUISIANA STATE M...|     William Cassidy|6767 Perkins Rd #100|         null|  Baton Rouge|     LA|   70808|        U|      Q|                null|               Q|     T|Louisiana State M...|     null|
# |C00001016|CARPENTERS LEGISL...|         Monte Byers|101 Constitution ...|         null|   Washington|     DC|   20001|        U|      Q|                 NNE|               M|     L|  UBC Local 1024 PAC|     null|
# |C00001081|DICKINSON SECOND ...|     LLOYD LANCASTER|   2350 WOODLEY ROAD|         null|   MONTGOMERY|     AL|   36111|        P|      H|                 REP|               T|  null|                null|H6AL02050|
# |C00001099|        D R I V E 42|         HUGO MORRIS|9300 FLAIR DRIVE ...|         null|     EL MONTE|     CA|   91731|        U|      Q|                 UNK|               T|     L|TEAMSTERS; INT'L ...|     null|
# |C00001156|MICHIGAN LEAGUE O...|     ROBERT G HOWELL|16837 THORNGATE ROAD|         null| EAST LANSING|     MI|   48823|        U|      Q|                null|               Q|     T|MICHIGAN LEAGUE O...|     null|
# +---------+--------------------+--------------------+--------------------+-------------+-------------+-------+--------+---------+-------+--------------------+----------------+------+--------------------+---------+
# only showing top 20 rows
#
# Starting 2002
# rm: cannot remove 'itcont.txt': No such file or directory
# 2002 Complete
# https://storage.googleapis.com/team5k/donations/cm04.zip
# --2020-08-03 14:07:11--  https://storage.googleapis.com/team5k/donations/cm04.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.203.128, 173.194.215.128, 172.217.193.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.203.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 465679 (455K) [application/x-zip-compressed]
# Saving to: ‘cm04.zip’
#
# cm04.zip            100%[===================>] 454.76K  --.-KB/s    in 0.003s
#
# 2020-08-03 14:07:11 (139 MB/s) - ‘cm04.zip’ saved [465679/465679]
#
# Archive:  cm04.zip
#   inflating: cm.txt
# +---------+--------------------+--------------------+--------------------+-------------+-------------+-------+--------+---------+-------+--------------------+----------------+------+--------------------+---------+
# |  CMTE_ID|             CMTE_NM|             TRES_NM|            CMTE_ST1|     CMTE_ST2|    CMTE_CITY|CMTE_ST|CMTE_ZIP|CMTE_DSGN|CMTE_TP|CMTE_PTY_AFFILIATION|CMTE_FILING_FREQ|ORG_TP|    CONNECTED_ORG_NM|  CAND_ID|
# +---------+--------------------+--------------------+--------------------+-------------+-------------+-------+--------+---------+-------+--------------------+----------------+------+--------------------+---------+
# |C00000042|ILLINOIS TOOL WOR...|    Michael J. Lynch| 3600 W. Lake Avenue|         null|     Glenview|     IL|   60025|        U|      Q|                null|               Q|     C|ILLINOIS TOOL WOR...|     null|
# |C00000059|HALLMARK POLITICA...|      GREG C SWARENS|2501 MCGEE STREET...|PO BOX 419580|  KANSAS CITY|     MO|   64141|        U|      Q|                 UNK|               M|     C|HALLMARK CARDS IN...|     null|
# |C00000125|ARCHER FOR CONGRE...|        MRS JO MARSH|2001 KIRBY DRIVE ...|            .|      HOUSTON|     TX|   77019|        P|      H|                 REP|               T|  null|                null|H6TX07029|
# |C00000372|MAINTENANCE OF WA...|GELLER, PERRY K. ...|20300 Civic Cente...|    Suite 320|   SOUTHFIELD|     MI|   48076|        U|      Q|                 UNK|               M|     L|BROTHERHOOD OF MA...|     null|
# |C00000422|AMERICAN MEDICAL ...|       WALKER, KEVIN|1101 VERMONT AVEN...|   12TH FLOOR|   WASHINGTON|     DC|   20005|        U|      Q|                null|               M|     T|MEDICAL ASS'N: AM...|     null|
# |C00000489|D R I V E POLITIC...|        ROBERT YOUNG|      3528 WEST RENO|         null|OKLAHOMA CITY|     OK|   73107|        U|      Q|                null|               Q|     L|TEAMSTERS; INT'L ...|     null|
# |C00000547|KANSAS MEDICAL SO...|C. RICHARD BONEBR...|     623 SW 10TH AVE|         null|       TOPEKA|     KS|   66612|        U|      Q|                 UNK|               Q|     T|MEDICAL ASS'N; KA...|     null|
# |C00000638|INDIANA MEDICAL P...|    Kora, Vidya M.D.|322 Canal Walk Ca...|            .| Indianapolis|     IN|   46202|        U|      Q|                null|               Q|     T|MEDICAL ASS'N: AM...|     null|
# |C00000729|AMERICAN DENTAL P...|        Edward Vigna| 1111 14th Street NW|   Suite 1100|   Washington|     DC|   20005|        U|      Q|                 UNK|               M|     T|DENTAL ASS'N; AME...|     null|
# |C00000794| LENT & SCRIVNER PAC|  MICHAEL S SCRIVNER|         PO BOX 2715|         null|    ARLINGTON|     VA|   22202|        U|      Q|                 UNK|               Q|  null|                null|     null|
# |C00000885|INTERNATIONAL UNI...|       Galis, George|1750 New York Ave...|            .|   Washington|     DC|   20006|        U|      Q|                 UNK|               M|     L|International Uni...|     null|
# |C00000901|BUILD POLITICAL A...|       JOSEPH BARNEY| 1201 15TH STREET NW|            .|   WASHINGTON|     DC|   20005|        U|      Q|                 UNK|               M|     T|HOME BUILDERS; NA...|     null|
# |C00000935|DEMOCRATIC CONGRE...|    Bonham, James J.|430 South Capitol...|    2nd Floor|   Washington|     DC|   20003|        U|      Y|                 DEM|               M|  null| Frontline Democrats|     null|
# |C00000984|UNITED STATES TEL...|       Edward Merlis|1401 H Street Nor...|    Suite 600|   Washington|     DC|   20005|        U|      Q|                 UNK|               M|     T|United States Tel...|     null|
# |C00000992|BRANCH COUNTY REP...|    RONALD E SAMPSEL|          PO BOX 127|            .|    COLDWATER|     MI|   49036|        U|      Y|                 REP|               Q|  null|MICHIGAN REPUBLIC...|     null|
# |C00001008|LOUISIANA STATE M...|     William Cassidy|6767 Perkins Rd #100|         null|  Baton Rouge|     LA|   70808|        U|      Q|                null|               Q|     T|Louisiana State M...|     null|
# |C00001016|CARPENTERS LEGISL...|         Monte Byers|101 Constitution ...|         null|   Washington|     DC|   20001|        U|      Q|                 NNE|               M|     L|  UBC Local 1024 PAC|     null|
# |C00001156|MICHIGAN LEAGUE O...|     ROBERT G HOWELL|16837 THORNGATE ROAD|         null| EAST LANSING|     MI|   48823|        U|      Q|                null|               Q|     T|MICHIGAN LEAGUE O...|     null|
# |C00001180|MICHIGAN DOCTORS ...| Grant, James Dr. MD|        P.O. Box 769|         null| East Lansing|     MI|   48826|        U|      Q|                 NNE|               Q|     T|MICHIGAN STATE ME...|     null|
# |C00001198|AMERICAN HOTEL AN...|         Jeon, Joori|1201 New York Ave...|  Sixth Floor|   Washington|     DC|   20005|        U|      Q|                null|               M|     T|HOTEL & MOTEL ASS...|     null|
# +---------+--------------------+--------------------+--------------------+-------------+-------------+-------+--------+---------+-------+--------------------+----------------+------+--------------------+---------+
# only showing top 20 rows
#
# Starting 2004
# rm: cannot remove 'itcont.txt': No such file or directory
# 2004 Complete
# https://storage.googleapis.com/team5k/donations/cm06.zip
# --2020-08-03 14:07:25--  https://storage.googleapis.com/team5k/donations/cm06.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.31.128, 173.194.217.128, 108.177.11.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.31.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 469614 (459K) [application/x-zip-compressed]
# Saving to: ‘cm06.zip’
#
# cm06.zip            100%[===================>] 458.61K  --.-KB/s    in 0.004s
#
# 2020-08-03 14:07:25 (115 MB/s) - ‘cm06.zip’ saved [469614/469614]
#
# Archive:  cm06.zip
#   inflating: cm.txt
# +---------+--------------------+--------------------+--------------------+----------------+-------------+-------+--------+---------+-------+--------------------+----------------+------+--------------------+-------+
# |  CMTE_ID|             CMTE_NM|             TRES_NM|            CMTE_ST1|        CMTE_ST2|    CMTE_CITY|CMTE_ST|CMTE_ZIP|CMTE_DSGN|CMTE_TP|CMTE_PTY_AFFILIATION|CMTE_FILING_FREQ|ORG_TP|    CONNECTED_ORG_NM|CAND_ID|
# +---------+--------------------+--------------------+--------------------+----------------+-------------+-------+--------+---------+-------+--------------------+----------------+------+--------------------+-------+
# |C00000042|ILLINOIS TOOL WOR...|    Michael J. Lynch| 3600 W. Lake Avenue|            null|     Glenview|     IL|   60025|        U|      Q|                null|               Q|     C|ILLINOIS TOOL WOR...|   null|
# |C00000059|  HALLMARK CARDS PAC|       Swarens, Greg|          2501 McGee|         MD #288|  Kansas City|     MO|   64108|        U|      Q|                 UNK|               M|     C|HALLMARK CARDS IN...|   null|
# |C00000372|MAINTENANCE OF WA...|GELLER, PERRY K. ...|20300 Civic Cente...|       Suite 320|   SOUTHFIELD|     MI|   48076|        U|      Q|                 UNK|               T|     L|               DRIVE|   null|
# |C00000422|AMERICAN MEDICAL ...|       WALKER, KEVIN|1101 VERMONT AVEN...|      12TH FLOOR|   WASHINGTON|     DC|   20005|        U|      Q|                null|               M|     T|MEDICAL ASS'N: AM...|   null|
# |C00000489|D R I V E POLITIC...|        ROBERT YOUNG|      3528 WEST RENO|            null|OKLAHOMA CITY|     OK|   73107|        U|      Q|                null|               Q|     L|TEAMSTERS LOCAL U...|   null|
# |C00000547|KANSAS MEDICAL SO...|C. RICHARD BONEBR...|     623 SW 10TH AVE|            null|       TOPEKA|     KS|   66612|        U|      Q|                 UNK|               Q|     T|MEDICAL ASS'N; KA...|   null|
# |C00000638|INDIANA STATE MED...| Hughes M.D., Gordon|322 Canal Walk Ca...|               .| Indianapolis|     IN|   46202|        U|      Q|                null|               Q|     T|Indiana State Med...|   null|
# |C00000729|AMERICAN DENTAL P...|Triftshauser, Rog...| 1111 14th Street NW|      Suite 1100|   Washington|     DC|   20005|        U|      Q|                 UNK|               M|     T|DENTAL ASS'N; AME...|   null|
# |C00000794| LENT & SCRIVNER PAC|  MICHAEL S SCRIVNER|         PO BOX 2715|            null|    ARLINGTON|     VA|   22202|        U|      Q|                 UNK|               Q|  null|                null|   null|
# |C00000885|INTERNATIONAL UNI...|       Galis, George|1750 New York Ave...|               .|   Washington|     DC|   20006|        U|      Q|                 UNK|               M|     L|International Uni...|   null|
# |C00000901|BUILD POLITICAL A...|       JOSEPH BARNEY| 1201 15TH STREET NW|               .|   WASHINGTON|     DC|   20005|        U|      Q|                 UNK|               M|     T|HOME BUILDERS; NA...|   null|
# |C00000935|DEMOCRATIC CONGRE...|          Lapp, John|430 South Capitol...|       2nd Floor|   Washington|     DC|   20003|        U|      Y|                 DEM|               M|  null|                   .|   null|
# |C00000984|UNITED STATES TEL...|       Edward Merlis|607 14th Street N...|       Suite 400|   Washington|     DC|   20005|        U|      Q|                 UNK|               M|     T|United States Tel...|   null|
# |C00000992|BRANCH COUNTY REP...| ROBERT L BARANOUSKI|          PO BOX 127|               .|    COLDWATER|     MI|   49036|        U|      Y|                 REP|               Q|  null|MICHIGAN REPUBLIC...|   null|
# |C00001008|LOUISIANA STATE M...|     William Cassidy|6767 Perkins Rd #100|            null|  Baton Rouge|     LA|   70808|        U|      Q|                null|               Q|     T|Louisiana State M...|   null|
# |C00001016|CARPENTERS LEGISL...|        Byers, Monte|101 Constitution ...|Tenth Floor West|   Washington|     DC|   20001|        U|      Q|                 NNE|               M|     L|United Brotherhoo...|   null|
# |C00001156|MICHIGAN LEAGUE O...|     ROBERT G HOWELL|16837 THORNGATE ROAD|            null| EAST LANSING|     MI|   48823|        U|      Q|                null|               Q|     T|MICHIGAN LEAGUE O...|   null|
# |C00001180|MICHIGAN DOCTORS ...| Scot F. Goldberg MD|        P.O. Box 769|            null| East Lansing|     MI|   48826|        U|      Q|                 NNE|               Q|     T|MICHIGAN STATE ME...|   null|
# |C00001198|AMERICAN HOTEL AN...|         Jeon, Joori|1201 New York Ave...|     Sixth Floor|   Washington|     DC|   20005|        U|      Q|                null|               M|     T|HOTEL & MOTEL ASS...|   null|
# |C00001214|TEXAS MEDICAL ASS...| Reynolds, David Mr.|401 West 15th Street|            null|       Austin|     TX|   78701|        U|      Q|                 NNE|               Q|     T|               AMPAC|   null|
# +---------+--------------------+--------------------+--------------------+----------------+-------------+-------+--------+---------+-------+--------------------+----------------+------+--------------------+-------+
# only showing top 20 rows
#
# Starting 2006
# rm: cannot remove 'itcont.txt': No such file or directory
# 2006 Complete
# https://storage.googleapis.com/team5k/donations/cm08.zip
# --2020-08-03 14:07:54--  https://storage.googleapis.com/team5k/donations/cm08.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.204.128, 172.217.203.128, 173.194.216.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.204.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 504959 (493K) [application/x-zip-compressed]
# Saving to: ‘cm08.zip’
#
# cm08.zip            100%[===================>] 493.12K  --.-KB/s    in 0.004s
#
# 2020-08-03 14:07:55 (120 MB/s) - ‘cm08.zip’ saved [504959/504959]
#
# Archive:  cm08.zip
#   inflating: cm.txt
# +---------+--------------------+--------------------+--------------------+----------------+-------------+-------+--------+---------+-------+--------------------+----------------+------+--------------------+-------+
# |  CMTE_ID|             CMTE_NM|             TRES_NM|            CMTE_ST1|        CMTE_ST2|    CMTE_CITY|CMTE_ST|CMTE_ZIP|CMTE_DSGN|CMTE_TP|CMTE_PTY_AFFILIATION|CMTE_FILING_FREQ|ORG_TP|    CONNECTED_ORG_NM|CAND_ID|
# +---------+--------------------+--------------------+--------------------+----------------+-------------+-------+--------+---------+-------+--------------------+----------------+------+--------------------+-------+
# |C00000042|ILLINOIS TOOL WOR...|    Michael J. Lynch| 3600 W. Lake Avenue|            null|     Glenview|     IL|   60025|        U|      Q|                null|               Q|     C|ILLINOIS TOOL WOR...|   null|
# |C00000059|  HALLMARK CARDS PAC|       Swarens, Greg|          2501 McGee|         MD #288|  Kansas City|     MO|   64108|        U|      Q|                 UNK|               M|     C|HALLMARK CARDS IN...|   null|
# |C00000422|AMERICAN MEDICAL ...|       WALKER, KEVIN|25 MASSACHUSETTS ...|       SUITE 600|   WASHINGTON|     DC|   20001|        U|      Q|                null|               M|     M|AMERICAN MEDICAL ...|   null|
# |C00000489|D R I V E POLITIC...|            RON COBB|      3528 WEST RENO|            null|OKLAHOMA CITY|     OK|   73107|        U|      Q|                null|               Q|     L|TEAMSTERS LOCAL U...|   null|
# |C00000547|KANSAS MEDICAL SO...|C. RICHARD BONEBR...|     623 SW 10TH AVE|            null|       TOPEKA|     KS|   66612|        U|      Q|                 UNK|               Q|     T|MEDICAL ASS'N; KA...|   null|
# |C00000638|INDIANA STATE MED...|   Kora, M.D., Vidya|322 Canal Walk, C...|               .| Indianapolis|     IN|   46202|        U|      Q|                null|               Q|     M|Indiana State Med...|   null|
# |C00000729|AMERICAN DENTAL P...|Triftshauser, Rog...| 1111 14th Street NW|      Suite 1100|   Washington|     DC|   20005|        U|      Q|                 UNK|               M|     T|DENTAL ASS'N; AME...|   null|
# |C00000794|LENT  & SCRIVNER PAC|  MICHAEL S SCRIVNER|         PO BOX 2715|            null|    ARLINGTON|     VA|   22202|        U|      Q|                 UNK|               T|  null|                null|   null|
# |C00000885|INTERNATIONAL UNI...|       Galis, George|1750 New York Ave...|               .|   Washington|     DC|   20006|        U|      Q|                 UNK|               M|     L|International Uni...|   null|
# |C00000901|BUILD POLITICAL A...|       JOSEPH BARNEY| 1201 15TH STREET NW|               .|   WASHINGTON|     DC|   20005|        U|      Q|                 UNK|               M|     T|HOME BUILDERS; NA...|   null|
# |C00000935|DEMOCRATIC CONGRE...|     Wolff, Brian L.|430 South Capitol...|       2nd Floor|   Washington|     DC|   20003|        U|      Y|                 DEM|               M|  null|House Senate Vict...|   null|
# |C00000984|UNITED STATES TEL...|    William R. Deere|607 14th Street N...|       Suite 400|   Washington|     DC|   20005|        U|      Q|                 UNK|               M|     T|United States Tel...|   null|
# |C00000992|BRANCH COUNTY REP...|      JON ERIC HOUTZ|          PO BOX 127|               .|    COLDWATER|     MI|   49036|        U|      Y|                 REP|               M|  null|MICHIGAN REPUBLIC...|   null|
# |C00001008|LOUISIANA STATE M...|     William Cassidy|6767 Perkins Rd #100|            null|  Baton Rouge|     LA|   70808|        U|      Q|                null|               Q|     T|Louisiana State M...|   null|
# |C00001016|CARPENTERS LEGISL...|        Byers, Monte|101 Constitution ...|Tenth Floor West|   Washington|     DC|   20001|        U|      Q|                 NNE|               M|     L|United Brotherhoo...|   null|
# |C00001156|MICHIGAN LEAGUE O...|     ROBERT G HOWELL|16837 THORNGATE ROAD|            null| EAST LANSING|     MI|   48823|        U|      Q|                null|               A|     T|MICHIGAN LEAGUE O...|   null|
# |C00001180|MICHIGAN DOCTORS ...| Scot F. Goldberg MD|        P.O. Box 769|            null| East Lansing|     MI|   48826|        U|      Q|                 NNE|               Q|     T|MICHIGAN STATE ME...|   null|
# |C00001198|AMERICAN HOTEL AN...|         Jeon, Joori|1201 New York Ave...|     Sixth Floor|   Washington|     DC|   20005|        U|      Q|                null|               M|     T|HOTEL & MOTEL ASS...|   null|
# |C00001214|TEXAS MEDICAL ASS...| Reynolds, David Mr.|401 West 15th Street|            null|       Austin|     TX|   78701|        U|      Q|                 NNE|               Q|     M|               AMPAC|   null|
# |C00001305|REPUBLICAN PARTY ...|Neel, Richard F M...|115 EAST GRACE ST...|               .|     RICHMOND|     VA|   23219|        U|      Y|                 Rep|               M|  null|2008 Senate-RNC V...|   null|
# +---------+--------------------+--------------------+--------------------+----------------+-------------+-------+--------+---------+-------+--------------------+----------------+------+--------------------+-------+
# only showing top 20 rows
#
# Starting 2008
# rm: cannot remove 'itcont.txt': No such file or directory
# 2008 Complete
# https://storage.googleapis.com/team5k/donations/cm10.zip
# --2020-08-03 14:08:01--  https://storage.googleapis.com/team5k/donations/cm10.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.204.128, 172.217.203.128, 74.125.31.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.204.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 512207 (500K) [application/x-zip-compressed]
# Saving to: ‘cm10.zip’
#
# cm10.zip            100%[===================>] 500.20K  --.-KB/s    in 0.005s
#
# 2020-08-03 14:08:01 (99.0 MB/s) - ‘cm10.zip’ saved [512207/512207]
#
# Archive:  cm10.zip
#   inflating: cm.txt
# +---------+--------------------+--------------------+--------------------+---------------+-------------+-------+---------+---------+-------+--------------------+----------------+------+--------------------+-------+
# |  CMTE_ID|             CMTE_NM|             TRES_NM|            CMTE_ST1|       CMTE_ST2|    CMTE_CITY|CMTE_ST| CMTE_ZIP|CMTE_DSGN|CMTE_TP|CMTE_PTY_AFFILIATION|CMTE_FILING_FREQ|ORG_TP|    CONNECTED_ORG_NM|CAND_ID|
# +---------+--------------------+--------------------+--------------------+---------------+-------------+-------+---------+---------+-------+--------------------+----------------+------+--------------------+-------+
# |C00000042|ILLINOIS TOOL WOR...|   LYNCH, MICHAEL J.|3600 WEST LAKE AV...|           null|     GLENVIEW|     IL|    60026|        B|      Q|                null|               Q|     C|ILLINOIS TOOL WOR...|   null|
# |C00000059|  HALLMARK CARDS PAC|     SWARENS, GREG  |          2501 MCGEE|        MD #288|  KANSAS CITY|     MO|    64108|        U|      Q|                 UNK|               M|     C|HALLMARK CARDS IN...|   null|
# |C00000422|AMERICAN MEDICAL ...|       WALKER, KEVIN|25 MASSACHUSETTS ...|      SUITE 600|   WASHINGTON|     DC|    20001|        B|      Q|                null|               M|     M|AMERICAN MEDICAL ...|   null|
# |C00000489|D R I V E POLITIC...|            RON COBB|      3528 WEST RENO|           null|OKLAHOMA CITY|     OK|    73107|        U|      Q|                null|               Q|     L|TEAMSTERS LOCAL U...|   null|
# |C00000547|KANSAS MEDICAL SO...|C. RICHARD BONEBR...|     623 SW 10TH AVE|           null|       TOPEKA|     KS|    66612|        U|      Q|                 UNK|               Q|     T|MEDICAL ASS'N; KA...|   null|
# |C00000638|INDIANA STATE MED...|   KORA, M.D., VIDYA|322 CANAL WALK, C...|           null| INDIANAPOLIS|     IN|    46202|        U|      Q|                null|               Q|     M|INDIANA STATE MED...|   null|
# |C00000729|AMERICAN DENTAL A...|  CONNOR, FRANCIS DR|1111 14TH STREET, NW|     SUITE 1100|   WASHINGTON|     DC|    20005|        B|      Q|                 UNK|               M|     M|AMERICAN DENTAL A...|   null|
# |C00000885|INTERNATIONAL UNI...|       GALIS, GEORGE|  7234 PARKWAY DRIVE|           null|      HANOVER|     MD|    21076|        B|      Q|                 UNK|               M|     L|INTERNATIONAL UNI...|   null|
# |C00000901|BUILD POLITICAL A...|      BARNEY, JOSEPH|1201 15TH STREET, NW|           null|   WASHINGTON|     DC|    20005|        B|      Q|                 UNK|               M|     T|NATIONAL ASSOCIAT...|   null|
# |C00000935|DEMOCRATIC CONGRE...|  VOGEL, JONATHAN S.|430 SOUTH CAPITOL...|      2ND FLOOR|   WASHINGTON|     DC|    20003|        U|      Y|                 DEM|               M|  null|RHODE ISLAND VICTORY|   null|
# |C00000984|UNITED STATES TEL...|   DEERE, WILLIAM R.|607 14TH STREET N...|      SUITE 400|   WASHINGTON|     DC|    20005|        B|      Q|                 UNK|               M|     T|UNITED STATES TEL...|   null|
# |C00000992|BRANCH COUNTY REP...|      JON ERIC HOUTZ|          PO BOX 127|              .|    COLDWATER|     MI|    49036|        U|      Y|                 REP|               Q|  null|MICHIGAN REPUBLIC...|   null|
# |C00001008|LOUISIANA STATE M...|     WILLIAM CASSIDY|6767 PERKINS RD #100|           null|  BATON ROUGE|     LA|    70808|        U|      Q|                null|               Q|     T|LOUISIANA STATE M...|   null|
# |C00001016|CARPENTERS LEGISL...|      SILINS, ANDRIS|101 CONSTIUTION A...|10TH FLOOR WEST|   WASHINGTON|     DC|    20001|        B|      Q|                 NNE|               M|     L|UNITED BROTHERHOO...|   null|
# |C00001180|MICHIGAN DOCTORS ...|SCOT F. GOLDBERG, MD|        P.O. BOX 769|           null| EAST LANSING|     MI|    48826|        U|      Q|                 NNE|               Q|     T|MICHIGAN STATE ME...|   null|
# |C00001198|AMERICAN HOTEL AN...|          JOORI JEON|1201 NEW YORK AVE...|    SIXTH FLOOR|   WASHINGTON|     DC|200053931|        U|      Q|                null|               M|     T|HOTEL & MOTEL ASS...|   null|
# |C00001214|TEXAS MEDICAL ASS...| REYNOLDS, DAVID MR.|401 WEST 15TH STREET|           null|       AUSTIN|     TX|    78701|        B|      Q|                 NNE|               Q|     T|               AMPAC|   null|
# |C00001305|REPUBLICAN PARTY ...|   PLUM, BRIAN K MR.|115 EAST GRACE ST...|           null|     RICHMOND|     VA|232191741|        U|      Y|                 REP|               M|  null|2008 SENATE-RNC V...|   null|
# |C00001313|REPUBLICAN PARTY ...|   STURROCK, DAVID E|     525 PARK STREET|      SUITE 250|      ST PAUL|     MN|    55103|        U|      Y|                 REP|               M|  null|MINNESOTA BACHMAN...|   null|
# |C00001347|HAWAII MEDICAL PO...|  SPANGLER, JOHN DR.|1360 S. BERETANIA...|           #200|     HONOLULU|     HI|    96814|        U|      Q|                 UNK|               Q|     M|HAWAII MEDICAL AS...|   null|
# +---------+--------------------+--------------------+--------------------+---------------+-------------+-------+---------+---------+-------+--------------------+----------------+------+--------------------+-------+
# only showing top 20 rows
#
# Starting 2010
# rm: cannot remove 'itcont.txt': No such file or directory
# 2010 Complete
# https://storage.googleapis.com/team5k/donations/cm12.zip
# --2020-08-03 14:08:08--  https://storage.googleapis.com/team5k/donations/cm12.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.31.128, 173.194.217.128, 108.177.11.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.31.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 608802 (595K) [application/x-zip-compressed]
# Saving to: ‘cm12.zip’
#
# cm12.zip            100%[===================>] 594.53K  --.-KB/s    in 0.005s
#
# 2020-08-03 14:08:08 (125 MB/s) - ‘cm12.zip’ saved [608802/608802]
#
# Archive:  cm12.zip
#   inflating: cm.txt
# +---------+--------------------+--------------------+--------------------+---------------+-------------+-------+---------+---------+-------+--------------------+----------------+------+--------------------+-------+
# |  CMTE_ID|             CMTE_NM|             TRES_NM|            CMTE_ST1|       CMTE_ST2|    CMTE_CITY|CMTE_ST| CMTE_ZIP|CMTE_DSGN|CMTE_TP|CMTE_PTY_AFFILIATION|CMTE_FILING_FREQ|ORG_TP|    CONNECTED_ORG_NM|CAND_ID|
# +---------+--------------------+--------------------+--------------------+---------------+-------------+-------+---------+---------+-------+--------------------+----------------+------+--------------------+-------+
# |C00000042|ILLINOIS TOOL WOR...|LYNCH, MICHAEL J....|3600 WEST LAKE AV...|           null|     GLENVIEW|     IL|    60026|        B|      Q|                null|               Q|     C|ILLINOIS TOOL WOR...|   null|
# |C00000059|  HALLMARK CARDS PAC|        GREG SWARENS|          2501 MCGEE|         MD#288|  KANSAS CITY|     MO|    64108|        U|      Q|                 UNK|               M|     C|                null|   null|
# |C00000422|AMERICAN MEDICAL ...|       WALKER, KEVIN|25 MASSACHUSETTS ...|      SUITE 600|   WASHINGTON|     DC|    20001|        B|      Q|                null|               M|     M|AMERICAN MEDICAL ...|   null|
# |C00000489|D R I V E POLITIC...|          TOM RITTER|         3528 W RENO|           null|OKLAHOMA CITY|     OK|    73107|        U|      N|                null|               Q|     L|TEAMSTERS LOCAL U...|   null|
# |C00000547|KANSAS MEDICAL SO...|C. RICHARD BONEBR...|     623 SW 10TH AVE|           null|       TOPEKA|     KS|    66612|        U|      Q|                 UNK|               Q|     T|MEDICAL ASS'N; KA...|   null|
# |C00000638|INDIANA STATE MED...|   KORA, M.D., VIDYA|322 CANAL WALK, C...|           null| INDIANAPOLIS|     IN|    46202|        U|      Q|                null|               Q|     M|INDIANA STATE MED...|   null|
# |C00000729|AMERICAN DENTAL A...| MCGINTY, CHARLES DR|1111 14TH STREET, NW|     SUITE 1100|   WASHINGTON|     DC|    20005|        B|      Q|                 UNK|               M|     M|AMERICAN DENTAL A...|   null|
# |C00000885|INTERNATIONAL UNI...|       GALIS, GEORGE|  7234 PARKWAY DRIVE|           null|      HANOVER|     MD|    21076|        B|      Q|                 UNK|               M|     L|INTERNATIONAL UNI...|   null|
# |C00000901|BUILD POLITICAL A...|      BARNEY, JOSEPH|1201 15TH STREET, NW|           null|   WASHINGTON|     DC|    20005|        B|      Q|                 UNK|               M|     T|NATIONAL ASSOCIAT...|   null|
# |C00000935|DEMOCRATIC CONGRE...|      WARD, KELLY C.|430 SOUTH CAPITOL...|      2ND FLOOR|   WASHINGTON|     DC|    20003|        U|      Y|                 DEM|               M|  null|NANCY PELOSI VICT...|   null|
# |C00000984|UNITED STATES TEL...|   DEERE, WILLIAM R.|607 14TH STREET N...|      SUITE 400|   WASHINGTON|     DC|    20005|        B|      Q|                 UNK|               M|     T|UNITED STATES TEL...|   null|
# |C00000992|BRANCH COUNTY REP...|   GEOFFREY EICKMANN|          PO BOX 127|              .|    COLDWATER|     MI|    49036|        U|      Y|                 REP|               Q|  null|                null|   null|
# |C00001008|LOUISIANA STATE M...|NOBLE JR., JOHN W...|6767 PERKINS RD S...|           null|  BATON ROUGE|     LA|708084263|        U|      Q|                null|               T|     M|                null|   null|
# |C00001016|CARPENTERS LEGISL...|      SILINS, ANDRIS|101 CONSTIUTION A...|10TH FLOOR WEST|   WASHINGTON|     DC|    20001|        B|      Q|                 NNE|               M|     L|UNITED BROTHERHOO...|   null|
# |C00001180|MICHIGAN DOCTORS ...|SCOT F. GOLDBERG, MD|        P.O. BOX 769|           null| EAST LANSING|     MI|    48826|        U|      Q|                 NNE|               Q|     T|MICHIGAN STATE ME...|   null|
# |C00001198|AMERICAN HOTEL AN...|     JEON, JOORI MS.|1201 NEW YORK AVE...|    SIXTH FLOOR|   WASHINGTON|     DC|    20005|        B|      Q|                null|               M|     T|AMERICAN HOTEL & ...|   null|
# |C00001214|TEXAS MEDICAL ASS...| REYNOLDS, DAVID MR.|401 WEST 15TH STREET|           null|       AUSTIN|     TX|    78701|        B|      Q|                 NNE|               Q|     T|               AMPAC|   null|
# |C00001305|REPUBLICAN PARTY ...|FITZSIMMONDS, ROB...|115 EAST GRACE ST...|           null|     RICHMOND|     VA|232191741|        U|      Y|                 REP|               M|  null|2008 SENATE-RNC V...|   null|
# |C00001313|REPUBLICAN PARTY ...|       SCHERER, BRON|     525 PARK STREET|      SUITE 250|   SAINT PAUL|     MN|551032145|        U|      Y|                 REP|               M|  null|                NONE|   null|
# |C00001347|HAWAII MEDICAL PO...|  SPANGLER, JOHN DR.|1360 S. BERETANIA...|           #200|     HONOLULU|     HI|    96814|        U|      Q|                 UNK|               Q|     M|HAWAII MEDICAL AS...|   null|
# +---------+--------------------+--------------------+--------------------+---------------+-------------+-------+---------+---------+-------+--------------------+----------------+------+--------------------+-------+
# only showing top 20 rows
#
# Starting 2012
# rm: cannot remove 'itcont.txt': No such file or directory
# 2012 Complete
# https://storage.googleapis.com/team5k/donations/cm14.zip
# --2020-08-03 14:08:16--  https://storage.googleapis.com/team5k/donations/cm14.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.193.128, 172.217.204.128, 172.217.203.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.193.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 624425 (610K) [application/x-zip-compressed]
# Saving to: ‘cm14.zip’
#
# cm14.zip            100%[===================>] 609.79K  --.-KB/s    in 0.005s
#
# 2020-08-03 14:08:16 (131 MB/s) - ‘cm14.zip’ saved [624425/624425]
#
# Archive:  cm14.zip
#   inflating: cm.txt
# +---------+--------------------+--------------------+--------------------+---------------+-------------+-------+---------+---------+-------+--------------------+----------------+------+--------------------+-------+
# |  CMTE_ID|             CMTE_NM|             TRES_NM|            CMTE_ST1|       CMTE_ST2|    CMTE_CITY|CMTE_ST| CMTE_ZIP|CMTE_DSGN|CMTE_TP|CMTE_PTY_AFFILIATION|CMTE_FILING_FREQ|ORG_TP|    CONNECTED_ORG_NM|CAND_ID|
# +---------+--------------------+--------------------+--------------------+---------------+-------------+-------+---------+---------+-------+--------------------+----------------+------+--------------------+-------+
# |C00000042|ILLINOIS TOOL WOR...|LYNCH, MICHAEL J....|3600 WEST LAKE AV...|           null|     GLENVIEW|     IL|    60026|        B|      Q|                null|               T|     C|                null|   null|
# |C00000059|  HALLMARK CARDS PAC|        GREG SWARENS|          2501 MCGEE|         MD#288|  KANSAS CITY|     MO|    64108|        U|      Q|                 UNK|               M|     C|                null|   null|
# |C00000422|AMERICAN MEDICAL ...|       WALKER, KEVIN|25 MASSACHUSETTS ...|      SUITE 600|   WASHINGTON|     DC|    20001|        B|      Q|                null|               M|     M|AMERICAN MEDICAL ...|   null|
# |C00000489|D R I V E POLITIC...|          TOM RITTER|         3528 W RENO|           null|OKLAHOMA CITY|     OK|    73107|        U|      N|                null|               Q|     L|TEAMSTERS LOCAL U...|   null|
# |C00000547|KANSAS MEDICAL SO...|C. RICHARD BONEBR...|     623 SW 10TH AVE|           null|       TOPEKA|     KS|    66612|        U|      Q|                 UNK|               Q|     T|                null|   null|
# |C00000638|INDIANA STATE MED...|    VIDYA KORA, M.D.|322 CANAL WALK, C...|           null| INDIANAPOLIS|     IN|    46202|        U|      Q|                null|               Q|     M|                null|   null|
# |C00000729|AMERICAN DENTAL A...|HARRISON, THOMAS ...|1111 14TH STREET, NW|     SUITE 1100|   WASHINGTON|     DC|    20005|        B|      Q|                 UNK|               M|     M|AMERICAN DENTAL A...|   null|
# |C00000885|INTERNATIONAL UNI...|       GALIS, GEORGE|  7234 PARKWAY DRIVE|           null|      HANOVER|     MD|    21076|        B|      Q|                 UNK|               M|     L|INTERNATIONAL UNI...|   null|
# |C00000901|BUILD POLITICAL A...|      RAMAGE, EILEEN|1201 15TH STREET, NW|           null|   WASHINGTON|     DC|    20005|        B|      Q|                 UNK|               M|     T|NATIONAL ASSOCIAT...|   null|
# |C00000935|DEMOCRATIC CONGRE...|      WARD, KELLY C.|430 SOUTH CAPITOL...|      2ND FLOOR|   WASHINGTON|     DC|    20003|        U|      Y|                 DEM|               M|  null|NANCY PELOSI VICT...|   null|
# |C00000984|UNITED STATES TEL...|       ROTH, ALAN J.|607 14TH STREET N...|      SUITE 400|   WASHINGTON|     DC|    20005|        B|      Q|                 UNK|               M|     T|UNITED STATES TEL...|   null|
# |C00000992|BRANCH COUNTY REP...|       RALPH SCHAFER|          PO BOX 127|              .|    COLDWATER|     MI|    49036|        U|      Y|                 REP|               T|  null|                null|   null|
# |C00001016|CARPENTERS LEGISL...|      SILINS, ANDRIS|101 CONSTIUTION A...|10TH FLOOR WEST|   WASHINGTON|     DC|    20001|        B|      Q|                 NNE|               M|     L|UNITED BROTHERHOO...|   null|
# |C00001180|MICHIGAN DOCTORS ...|SCOT F. GOLDBERG, MD|        P.O. BOX 769|           null| EAST LANSING|     MI|    48826|        U|      Q|                 NNE|               Q|     T|MICHIGAN STATE ME...|   null|
# |C00001198|AMERICAN HOTEL AN...|     JEON, JOORI MS.|1201 NEW YORK AVE...|    SIXTH FLOOR|   WASHINGTON|     DC|    20005|        B|      Q|                null|               M|     T|AMERICAN HOTEL & ...|   null|
# |C00001214|TEXAS MEDICAL ASS...|STEWART, CLAYTON MR.|401 WEST 15TH STREET|           null|       AUSTIN|     TX|    78701|        B|      Q|                 NNE|               Q|     T|               AMPAC|   null|
# |C00001305|REPUBLICAN PARTY ...|NILSEN, RICHARD A...|115 EAST GRACE ST...|           null|     RICHMOND|     VA|232191741|        U|      Y|                 REP|               M|  null|GILLESPIE VICTORY...|   null|
# |C00001313|REPUBLICAN PARTY ...|       SCHERER, BRON|2200 E  FRANKLIN ...|      SUITE 201|  MINNEAPOLIS|     MN|554042395|        U|      Y|                 REP|               M|  null|TARGETED STATE VI...|   null|
# |C00001347|HAWAII MEDICAL PO...|  SPANGLER, JOHN DR.|1360 S. BERETANIA...|           #200|     HONOLULU|     HI|    96814|        U|      Q|                 UNK|               Q|     M|HAWAII MEDICAL AS...|   null|
# |C00001388|DAIRY FARMERS OF ...|         STONE, J.S.|     P.O. BOX 909700|           null|  KANSAS CITY|     MO|641909700|        B|      Q|                null|               M|     V|DAIRY FARMERS OF ...|   null|
# +---------+--------------------+--------------------+--------------------+---------------+-------------+-------+---------+---------+-------+--------------------+----------------+------+--------------------+-------+
# only showing top 20 rows
#
# Starting 2014
# rm: cannot remove 'itcont.txt': No such file or directory
# 2014 Complete
# https://storage.googleapis.com/team5k/donations/cm16.zip
# --2020-08-03 14:08:24--  https://storage.googleapis.com/team5k/donations/cm16.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.214.128, 173.194.217.128, 172.217.193.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.214.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 732217 (715K) [application/x-zip-compressed]
# Saving to: ‘cm16.zip’
#
# cm16.zip            100%[===================>] 715.06K  --.-KB/s    in 0.007s
#
# 2020-08-03 14:08:24 (104 MB/s) - ‘cm16.zip’ saved [732217/732217]
#
# Archive:  cm16.zip
#   inflating: cm.txt
# +---------+--------------------+--------------------+--------------------+---------------+-------------+-------+---------+---------+-------+--------------------+----------------+------+--------------------+-------+
# |  CMTE_ID|             CMTE_NM|             TRES_NM|            CMTE_ST1|       CMTE_ST2|    CMTE_CITY|CMTE_ST| CMTE_ZIP|CMTE_DSGN|CMTE_TP|CMTE_PTY_AFFILIATION|CMTE_FILING_FREQ|ORG_TP|    CONNECTED_ORG_NM|CAND_ID|
# +---------+--------------------+--------------------+--------------------+---------------+-------------+-------+---------+---------+-------+--------------------+----------------+------+--------------------+-------+
# |C00000059|  HALLMARK CARDS PAC|         ERIN BROWER|          2501 MCGEE|         MD#288|  KANSAS CITY|     MO|    64108|        U|      Q|                 UNK|               M|     C|                null|   null|
# |C00000422|AMERICAN MEDICAL ...|       WALKER, KEVIN|25 MASSACHUSETTS ...|      SUITE 600|   WASHINGTON|     DC|    20001|        B|      Q|                null|               M|     M|AMERICAN MEDICAL ...|   null|
# |C00000489|D R I V E POLITIC...|          TOM RITTER|         3528 W RENO|           null|OKLAHOMA CITY|     OK|    73107|        U|      N|                null|               Q|     L|TEAMSTERS LOCAL U...|   null|
# |C00000547|KANSAS MEDICAL SO...|C. RICHARD BONEBR...|     623 SW 10TH AVE|           null|       TOPEKA|     KS|    66612|        U|      Q|                 UNK|               Q|     T|                null|   null|
# |C00000638|INDIANA STATE MED...|    VIDYA KORA, M.D.|322 CANAL WALK, C...|           null| INDIANAPOLIS|     IN|    46202|        U|      Q|                null|               Q|     M|                null|   null|
# |C00000729|AMERICAN DENTAL A...|HARRISON, THOMAS ...|1111 14TH STREET, NW|     SUITE 1100|   WASHINGTON|     DC|    20005|        B|      Q|                 UNK|               M|     M|AMERICAN DENTAL A...|   null|
# |C00000885|INTERNATIONAL UNI...|       GALIS, GEORGE|  7234 PARKWAY DRIVE|           null|      HANOVER|     MD|    21076|        B|      Q|                 UNK|               M|     L|INTERNATIONAL UNI...|   null|
# |C00000901|BUILD POLITICAL A...|      RAMAGE, EILEEN|1201 15TH STREET, NW|           null|   WASHINGTON|     DC|    20005|        B|      Q|                 UNK|               M|     T|NATIONAL ASSOCIAT...|   null|
# |C00000935|                DCCC|      WARD, KELLY C.|430 SOUTH CAPITOL...|      2ND FLOOR|   WASHINGTON|     DC|200034024|        U|      Y|                 DEM|               M|  null|                null|   null|
# |C00000984|UNITED STATES TEL...|     VERSAGGI, SARAH|607 14TH STREET N...|      SUITE 400|   WASHINGTON|     DC|    20005|        B|      Q|                 UNK|               M|     T|UNITED STATES TEL...|   null|
# |C00001016|CARPENTERS LEGISL...|      SILINS, ANDRIS|101 CONSTIUTION A...|10TH FLOOR WEST|   WASHINGTON|     DC|    20001|        B|      Q|                 NNE|               M|     L|UNITED BROTHERHOO...|   null|
# |C00001180|MICHIGAN DOCTORS ...|SCOT F. GOLDBERG, MD|        P.O. BOX 769|           null| EAST LANSING|     MI|    48826|        U|      Q|                 NNE|               Q|     T|MICHIGAN STATE ME...|   null|
# |C00001198|AMERICAN HOTEL AN...|JEON, JOORI MS. C...|1250 I STREET, NW...|           null|   WASHINGTON|     DC|    20005|        B|      Q|                null|               M|     T|                null|   null|
# |C00001214|TEXAS MEDICAL ASS...|STEWART, CLAYTON MR.|401 WEST 15TH STREET|           null|       AUSTIN|     TX|    78701|        B|      Q|                 NNE|               Q|     T|               AMPAC|   null|
# |C00001305|REPUBLICAN PARTY ...|   SELPH, JOHN G MR.|115 EAST GRACE ST...|           null|     RICHMOND|     VA|232191741|        U|      Y|                 REP|               M|  null|GILLESPIE VICTORY...|   null|
# |C00001313|REPUBLICAN PARTY ...|       SCHERER, BRON|2200 E  FRANKLIN ...|      SUITE 201|  MINNEAPOLIS|     MN|554042395|        U|      Y|                 REP|               M|  null|TRUMP VICTORY C/O...|   null|
# |C00001347|HAWAII MEDICAL PO...|  SPANGLER, JOHN DR.|1360 S. BERETANIA...|           #200|     HONOLULU|     HI|    96814|        U|      Q|                 UNK|               Q|     M|HAWAII MEDICAL AS...|   null|
# |C00001388|DAIRY FARMERS OF ...|         STONE, J.S.|     P.O. BOX 909700|           null|  KANSAS CITY|     MO|641909700|        B|      Q|                null|               M|     V|DAIRY FARMERS OF ...|   null|
# |C00001461|ALASKA STATE MEDI...|ELLERBE, DWIGHT DR. |  4107 LAUREL STREET|           null|    ANCHORAGE|     AK|    99508|        U|      Q|                null|               Q|     M|ALASKA STATE MEDI...|   null|
# |C00001636|UNITED TRANSPORTA...| LESNIEWSKI, JOHN E.|24950 COUNTRY CLU...|           null|NORTH OLMSTED|     OH|    44070|        B|      Q|                null|               M|     L|UNITED TRANSPORTA...|   null|
# +---------+--------------------+--------------------+--------------------+---------------+-------------+-------+---------+---------+-------+--------------------+----------------+------+--------------------+-------+
# only showing top 20 rows
#
# Starting 2016
# rm: cannot remove 'itcont.txt': No such file or directory
# 2016 Complete
# All Years Complete

# %%
etl_load('committees', 'https://storage.googleapis.com/team5k/donations/', 'cm18.zip','2018')
etl_load('committees', 'https://storage.googleapis.com/team5k/donations/', 'cm20.zip','2020')
# Out:
# https://storage.googleapis.com/team5k/donations/cm18.zip
# --2020-08-04 13:55:59--  https://storage.googleapis.com/team5k/donations/cm18.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.217.128, 64.233.170.128, 108.177.11.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.217.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 809512 (791K) [application/x-zip-compressed]
# Saving to: ‘cm18.zip’
#
# cm18.zip            100%[===================>] 790.54K  --.-KB/s    in 0.007s
#
# 2020-08-04 13:55:59 (106 MB/s) - ‘cm18.zip’ saved [809512/809512]
#
# Archive:  cm18.zip
#   inflating: cm.txt
# +---------+--------------------+--------------------+--------------------+---------------+-------------+-------+---------+---------+-------+--------------------+----------------+------+--------------------+---------+
# |  CMTE_ID|             CMTE_NM|             TRES_NM|            CMTE_ST1|       CMTE_ST2|    CMTE_CITY|CMTE_ST| CMTE_ZIP|CMTE_DSGN|CMTE_TP|CMTE_PTY_AFFILIATION|CMTE_FILING_FREQ|ORG_TP|    CONNECTED_ORG_NM|  CAND_ID|
# +---------+--------------------+--------------------+--------------------+---------------+-------------+-------+---------+---------+-------+--------------------+----------------+------+--------------------+---------+
# |C00000018|IRONWORKERS LOCAL...|     STEVEN N GULICK|     43335 W 10 MILE|    P O BOX 965|         NOVI|     MI|    48050|        U|      Q|                null|               T|  null|IRON WORKERS; INT...|H8TX22313|
# |C00000059|  HALLMARK CARDS PAC|           SARAH MOE|          2501 MCGEE|        MD #500|  KANSAS CITY|     MO|    64108|        U|      Q|                 UNK|               M|     C|                null|     null|
# |C00000422|AMERICAN MEDICAL ...|   WALKER, KEVIN MR.|25 MASSACHUSETTS ...|      SUITE 600|   WASHINGTON|     DC|200017400|        B|      Q|                null|               M|     M|DELAWARE MEDICAL PAC|     null|
# |C00000489|D R I V E POLITIC...|          TOM RITTER|         3528 W RENO|           null|OKLAHOMA CITY|     OK|    73107|        U|      N|                null|               Q|     L|TEAMSTERS LOCAL U...|     null|
# |C00000547|KANSAS MEDICAL SO...|     JERRY SLAUGHTER|     623 SW 10TH AVE|           null|       TOPEKA|     KS|666121627|        U|      Q|                 UNK|               Q|     M|KANSAS MEDICAL SO...|     null|
# |C00000638|INDIANA STATE MED...|ACHENBACH, GRANT MR.|322 CANAL WALK, C...|           null| INDIANAPOLIS|     IN|    46202|        U|      Q|                null|               Q|     M|INDIANA STATE MED...|     null|
# |C00000729|AMERICAN DENTAL A...|ORTEGO, L STEPHEN...|1111 14TH STREET, NW|     SUITE 1100|   WASHINGTON|     DC|200055627|        B|      Q|                 UNK|               M|     T|NEW JERSEY DENTAL...|     null|
# |C00000885|INTERNATIONAL UNI...|       GALIS, GEORGE|  7234 PARKWAY DRIVE|           null|      HANOVER|     MD|    21076|        B|      Q|                 UNK|               M|     L|INTERNATIONAL UNI...|     null|
# |C00000901|BUILD POLITICAL A...|      RAMAGE, EILEEN|1201 15TH STREET, NW|           null|   WASHINGTON|     DC|    20005|        B|      Q|                 UNK|               M|     T|NATIONAL ASSOCIAT...|     null|
# |C00000935|                DCCC|        SENA, DANIEL|430 SOUTH CAPITOL...|      2ND FLOOR|   WASHINGTON|     DC|200034024|        U|      Y|                 DEM|               M|  null|                null|     null|
# |C00000984|UNITED STATES TEL...|        ROEHL, GALEN|601 NEW JERSEY AV...|      SUITE 600|   WASHINGTON|     DC|    20001|        B|      Q|                 UNK|               M|     T|UNITED STATES TEL...|     null|
# |C00001016|CARPENTERS LEGISL...|      SILINS, ANDRIS|101 CONSTIUTION A...|10TH FLOOR WEST|   WASHINGTON|     DC|    20001|        B|      Q|                 NNE|               M|     L|UNITED BROTHERHOO...|     null|
# |C00001180|MICHIGAN DOCTORS ...|      GHOSE, AMIT MD|        P.O. BOX 769|           null| EAST LANSING|     MI|    48826|        U|      Q|                 NNE|               Q|     T|MICHIGAN STATE ME...|     null|
# |C00001198|AMERICAN HOTEL AN...|     MASON, DAVID M.|1250 EYE STREET, ...|           null|   WASHINGTON|     DC|200055904|        B|      Q|                null|               M|     T|                null|     null|
# |C00001214|TEXAS MEDICAL ASS...|MOJEZATI, CHRISTI...|401 WEST 15TH STREET|           null|       AUSTIN|     TX|    78701|        B|      Q|                 NNE|               Q|     T|               AMPAC|     null|
# |C00001305|REPUBLICAN PARTY ...|   SELPH, JOHN G MR.|115 EAST GRACE ST...|           null|     RICHMOND|     VA|232191741|        U|      Y|                 REP|               M|  null|NRSC TARGETED STA...|     null|
# |C00001313|REPUBLICAN PARTY ...|       SCHERER, BRON|2200 E  FRANKLIN ...|      SUITE 201|  MINNEAPOLIS|     MN|554042395|        U|      Y|                 REP|               M|  null|   PROTECT THE HOUSE|     null|
# |C00001347|HAWAII MEDICAL PO...|  SPANGLER, JOHN DR.|1360 S. BERETANIA...|           #200|     HONOLULU|     HI|    96814|        U|      Q|                 UNK|               A|     M|                null|     null|
# |C00001388|DAIRY FARMERS OF ...|KLIPPENSTEIN, JACKIE| 1405 N. 98TH STREET|           null|  KANSAS CITY|     KS|    66111|        B|      Q|                null|               M|     V|DAIRY FARMERS OF ...|     null|
# |C00001461|ALASKA STATE MEDI...|ELLERBE, DWIGHT DR. |  4107 LAUREL STREET|           null|    ANCHORAGE|     AK|    99508|        U|      Q|                null|               Q|     M|ALASKA STATE MEDI...|     null|
# +---------+--------------------+--------------------+--------------------+---------------+-------------+-------+---------+---------+-------+--------------------+----------------+------+--------------------+---------+
# only showing top 20 rows
#
# Starting 2018
# rm: cannot remove 'itcont.txt': No such file or directory
# 2018 Complete
# https://storage.googleapis.com/team5k/donations/cm20.zip
# --2020-08-04 13:56:15--  https://storage.googleapis.com/team5k/donations/cm20.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.217.128, 172.217.193.128, 172.217.204.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.217.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 727610 (711K) [application/x-zip-compressed]
# Saving to: ‘cm20.zip’
#
# cm20.zip            100%[===================>] 710.56K  --.-KB/s    in 0.005s
#
# 2020-08-04 13:56:15 (135 MB/s) - ‘cm20.zip’ saved [727610/727610]
#
# Archive:  cm20.zip
#   inflating: cm.txt
# +---------+--------------------+--------------------+--------------------+---------------+-------------+-------+---------+---------+-------+--------------------+----------------+------+--------------------+-------+
# |  CMTE_ID|             CMTE_NM|             TRES_NM|            CMTE_ST1|       CMTE_ST2|    CMTE_CITY|CMTE_ST| CMTE_ZIP|CMTE_DSGN|CMTE_TP|CMTE_PTY_AFFILIATION|CMTE_FILING_FREQ|ORG_TP|    CONNECTED_ORG_NM|CAND_ID|
# +---------+--------------------+--------------------+--------------------+---------------+-------------+-------+---------+---------+-------+--------------------+----------------+------+--------------------+-------+
# |C00000059|  HALLMARK CARDS PAC|           SARAH MOE|          2501 MCGEE|        MD #500|  KANSAS CITY|     MO|    64108|        U|      Q|                 UNK|               M|     C|                null|   null|
# |C00000422|AMERICAN MEDICAL ...|   WALKER, KEVIN MR.|25 MASSACHUSETTS ...|      SUITE 600|   WASHINGTON|     DC|200017400|        B|      Q|                null|               M|     M|DELAWARE MEDICAL PAC|   null|
# |C00000489|D R I V E POLITIC...|       JERRY SIMS JR|         3528 W RENO|           null|OKLAHOMA CITY|     OK|    73107|        U|      N|                null|               Q|     L|                null|   null|
# |C00000547|KANSAS MEDICAL SO...|     JERRY SLAUGHTER|     623 SW 10TH AVE|           null|       TOPEKA|     KS|666121627|        U|      Q|                 UNK|               Q|     M|KANSAS MEDICAL SO...|   null|
# |C00000638|INDIANA STATE MED...|ACHENBACH, GRANT MR.|322 CANAL WALK, C...|           null| INDIANAPOLIS|     IN|    46202|        U|      Q|                null|               T|     M|                null|   null|
# |C00000729|AMERICAN DENTAL A...|  BARNES, BRAD W DR.|1111 14TH STREET, NW|     SUITE 1100|   WASHINGTON|     DC|200055627|        B|      Q|                 UNK|               M|     M|  INDIANA DENTAL PAC|   null|
# |C00000885|INTERNATIONAL UNI...|       GALIS, GEORGE|  7234 PARKWAY DRIVE|           null|      HANOVER|     MD|    21076|        B|      Q|                 UNK|               M|     L|INTERNATIONAL UNI...|   null|
# |C00000901|BUILD POLITICAL A...|      RAMAGE, EILEEN|1201 15TH STREET, NW|           null|   WASHINGTON|     DC|    20005|        B|      Q|                 UNK|               M|     T|NATIONAL ASSOCIAT...|   null|
# |C00000935|                DCCC|      GUINN, LUCINDA|430 SOUTH CAPITOL...|      2ND FLOOR|   WASHINGTON|     DC|200034024|        U|      Y|                 DEM|               M|  null|                null|   null|
# |C00000984|UNITED STATES TEL...|     HEINER, BRANDON|601 NEW JERSEY AV...|        STE 600|   WASHINGTON|     DC|    20001|        B|      Q|                 UNK|               M|     T|UNITED STATES TEL...|   null|
# |C00001016|CARPENTERS LEGISL...|       FLYNN, THOMAS|101 CONSTIUTION A...|10TH FLOOR WEST|   WASHINGTON|     DC|    20001|        B|      Q|                 NNE|               M|     L|UNITED BROTHERHOO...|   null|
# |C00001180|MICHIGAN DOCTORS ...|      GHOSE, AMIT MD|        P.O. BOX 769|           null| EAST LANSING|     MI|    48826|        U|      Q|                 NNE|               Q|     T|MICHIGAN STATE ME...|   null|
# |C00001198|AMERICAN HOTEL AN...|     MASON, DAVID M.|1250 EYE STREET, ...|           null|   WASHINGTON|     DC|200055904|        B|      Q|                null|               M|     T|                null|   null|
# |C00001214|TEXAS MEDICAL ASS...|MOJEZATI, CHRISTI...|401 WEST 15TH STREET|           null|       AUSTIN|     TX|    78701|        B|      Q|                 NNE|               Q|     T|               AMPAC|   null|
# |C00001305|REPUBLICAN PARTY ...|   SELPH, JOHN G MR.|115 EAST GRACE ST...|           null|     RICHMOND|     VA|232191741|        U|      Y|                 REP|               M|  null|RIGGLEMAN VICTORY...|   null|
# |C00001313|REPUBLICAN PARTY ...|       SCHERER, BRON|     7400 METRO BLVD|        STE 424|  MINNEAPOLIS|     MN|554392374|        U|      Y|                 REP|               M|  null|                NONE|   null|
# |C00001388|DAIRY FARMERS OF ...|KLIPPENSTEIN, JACKIE| 1405 N. 98TH STREET|           null|  KANSAS CITY|     KS|    66111|        B|      Q|                null|               M|     V|DAIRY FARMERS OF ...|   null|
# |C00001461|ALASKA STATE MEDI...|    HAUGEN, MIKE MR.|  4107 LAUREL STREET|           null|    ANCHORAGE|     AK|    99508|        U|      Q|                 NAT|               Q|     M|ALASKA STATE MEDI...|   null|
# |C00001636|        SMART TD PAC|   LEONARD, BRENT C.|24950 COUNTRY CLU...|           null|NORTH OLMSTED|     OH|    44070|        B|      Q|                null|               M|     L|            SMART TD|   null|
# |C00001727|BUSINESS-INDUSTRY...|  JOHN E. PALLAT III|   1707 L STREET, NW|           null|   WASHINGTON|     DC|    20036|        U|      W|                 UNK|               M|  null|                null|   null|
# +---------+--------------------+--------------------+--------------------+---------------+-------------+-------+---------+---------+-------+--------------------+----------------+------+--------------------+-------+
# only showing top 20 rows
#
# Starting 2020
# rm: cannot remove 'itcont.txt': No such file or directory
# 2020 Complete
